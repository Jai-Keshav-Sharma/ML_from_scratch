# %% [markdown]
# <a href="https://colab.research.google.com/github/Jai-Keshav-Sharma/ML_from_scratch/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
data = load_iris()
X = data.data
y = data.target

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
dbscan = DBSCAN(eps=0.5, min_samples=3)
labels = dbscan.fit_predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.xlabel("feature 1 (scaled)")
plt.ylabel("feature 2 (scaled)")
plt.title("DBSCAN on Iris (labels shown, -1 = noise)")
plt.show()

# %%
np.unique(labels, return_counts=True)
# Out:
# (array([-1,  0,  1,  2,  3,  4,  5,  6]),
#  array([17, 45, 73,  3,  3,  3,  3,  3]))
